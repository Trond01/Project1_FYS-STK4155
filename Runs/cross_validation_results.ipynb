# %%
import sys, os
sys.path.append(os.path.abspath(os.path.join('..')))

from Code.utilities import path_to_results
from Code.cross_validation import cross_validation_experiment

# %%
_ = cross_validation_experiment(5, n_points=100, num_features=50, filename = path_to_results("f).png"))
_ = cross_validation_experiment(5, n_points=1000, num_features=50, filename = path_to_results("f).png"))
