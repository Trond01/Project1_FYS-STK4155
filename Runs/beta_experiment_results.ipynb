# %%
import sys, os
sys.path.append(os.path.abspath(os.path.join('..')))


from Code.experiments import plot_beta_experiment
from Code.utilities import path_to_results, number_of_features
from Code.regression import train_OLS, train_RIDGE, train_LASSO

# %%
_ = plot_beta_experiment(train_OLS,   [0, 1, 2, 3, 10, 15], 50, 151, filename=path_to_results("beta_a_OLS.png"))
_ = plot_beta_experiment(train_RIDGE, [0, 1, 2, 3, 10, 15], 50, 151, filename=path_to_results("beta_a_RIDGE.png"), lam=10**(-3))
_ = plot_beta_experiment(train_LASSO, [0, 1, 2, 3, 10, 15], 50, 151, filename=path_to_results("beta_a_LASSO.png"), lam=10**(-3))
